# %%
import torch  # torch is the deep learning library we'll use
print(torch.cuda.is_available())  # Should print: True
print(torch.cuda.get_device_name(0))  # Prints GPU model name
# Out:
# True
# Tesla T4

# %%
# Install all libraries we'll need for this project

# !pip install torch torchvision torchaudio
# !pip install transformers
# !pip install biopython
# !pip install scikit-learn
# !pip install pandas numpy matplotlib seaborn
# !pip install kaggle
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 54.3 MB/s eta 0:00:00
# ...

# %%
# Mount Google Drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Create project folder

import os

project_path = '/content/drive/MyDrive/protein_function_prediction'

os.makedirs(project_path, exist_ok=True)

print(f"Project folder created at: {project_path}")
# Out:
# Project folder created at: /content/drive/MyDrive/protein_function_prediction

# %%
# !git config --global user.name "Bhoomika Nadella"
# !git config --global user.email "bhoomi.nadella@gmail.com"

# %%
# !git clone https://github.com/BhoomikaNadella/protein-function-prediction.git
# Out:
# Cloning into 'protein-function-prediction'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# %cd protein-function-prediction
# Out:
# /content/protein-function-prediction

# %%
from google.colab import files
import shutil

# Copy the notebook we're working in to the repo folder
shutil.copy('/content/protein_function_prediction_phase1.ipynb',
            '/content/protein-function-prediction/phase1_colab_setup.ipynb')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_862/745581384.py in <cell line: 0>()
#       3
#       4 # Copy the notebook we're working in to the repo folder
# ----> 5 shutil.copy('/content/protein_function_prediction_phase1.ipynb',
#       6             '/content/protein-function-prediction/phase1_colab_setup.ipynb')
#
# /usr/lib/python3.12/shutil.py in copy(src, dst, follow_symlinks)
#     433     if os.path.isdir(dst):
#     434         dst = os.path.join(dst, os.path.basename(src))
# --> 435     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     436     copymode(src, dst, follow_symlinks=follow_symlinks)
#     437     return dst
#
# /usr/lib/python3.12/shutil.py in copyfile(src, dst, follow_symlinks)
#     258         os.symlink(os.readlink(src), dst)
#     259     else:
# --> 260         with open(src, 'rb') as fsrc:
#     261             try:
# ...
